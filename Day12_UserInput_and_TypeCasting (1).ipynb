# %%
user accepted input:

# %%
message=input("Tell me something and i will repeat it for you:") #accepting theinput from user
print(message)
# Out:
# Tell me something and i will repeat it for you:Hey,How are you??
# Hey,How are you??

# %%
writing clear prompts:

# %%
name=input('please enter your name :')
print(f"\nHello, {name}.")
# Out:
# please enter your name :Shafi
#
# Hello, Shafi.

# %%
prompt="If you tell us who you are we can personalise the message for you"
prompt+="\nWhat is your first name"

# %%
name=input(prompt)
print(f"\nHello,{name}")
# Out:
# If you tell us who you are we can personalise the message for you
# What is your first nameShaik
#
# Hello,Shaik

# %%
#Note:By default input method will be accepting the input in string format**

# %%
age=input("How old are you??")
# Out:
# How old are you??32

# %%
age>=21
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-494ab093ff5c> in <module>
# ----> 1 age>=21
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
type(age)
# Out:
# str

# %%
#we gave input as int,but by default it took as string...for this we have to type cast it

# %%
TYPE CASTING OF THE DATATYPES:

# %%
age=input("How old are you??")
# Out:
# How old are you??32

# %%
age=int(age)

# %%
age>=21
# Out:
# True

# %%
type(age)
# Out:
# int

# %%
#REQ:take input of height from user and validate whether he can ride bike or not!!

# %%
height=input("How Tall Are You??")
height=int(height)  #type casting

if height>=48:
    print("\nYou can ride the bike!!")
else:
    print("\nYou can't ride bike,try again when you grow up!!!")
# Out:
# How Tall Are You??55
#
# You can ride the bike!!

# %%
Modulo Operator: ------>It will be doing a division operation and returning the remiainder

# %%
4%3
# Out:
# 1

# %%
6%3
# Out:
# 0

# %%
6/3
# Out:
# 2.0

# %%
Req:even or odd by user:

# %%
num=input("ENTER A NUMBER AND I WILL TELL WHETHER IT IS ODD OR EVEN :")
num=int(num)
# Out:
# ENTER A NUMBER AND I WILL TELL WHETHER IT IS ODD OR EVEN :24

# %%
if num%2==0:
    print("\nthe given number is even")
else:
    print("\nthe given number is odd")
# Out:
# the given number is even
