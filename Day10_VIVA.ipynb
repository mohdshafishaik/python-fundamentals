# %%
#BATCH_28:MOCK INTERVIEW SESSION

# %%
#Concepts tested for the day
#1.) String
#2.)list
#----->if conditiona and for loop
#3.)tuple
#4.)dictionary

# %%
#1.WHAT IS A STRING??
#ANS.) STRING IS NOTHING BUT SERIES OF CHARACTERS.

# %%
#2.)WHAT IS THE USE OF F'STRING??
#ANS.) WE USE THE F'STRING TO FORMAT A STRING WITH A VARIABLE WE JUST ASSIGNED/ALTERED...
#GENERAL SYNTAX=>f'{}'------>here "{}" acts as a place holder for the variable...
#we can also use this for adding our required string's in it

# %%
#3.) WHAT IS A LIST??
#ANS.) LIST IS A SERIES OF ITEMS ARRANGED IN AN ORDER..

# %%
#4.) WHAT IS THE SYNTAX OF FOR LOOP???
#ANS.) THE SYNTAX OF FOR LOOP IS :-
      for tempvariable in mainvariable:
        print(tempvariable)  #------->here,tempvariable can be assigned  as anything

# %%
#5.) WHAT IS THE DIIFERENCE BETWEEN SORT AND SORTED??
#ANS.) SORT AND SORTED ARE USED TO ENCHANCE A LIST INA ALPHABETICAL ORDER
#   SORT ENHANCES THE LIST PERMANENTLY
# AND...SORTED ENHANCES TEMPORARILY

# %%
#6.) WHAT IS A TUPLE DATATYPE??
#ANS.) TUPLE IS NOTHING BUT A LIST WHICH IS IMMUTABLE AND IS DEFINED IN PARENTHESIS i.e..()

# %%
#7.) WHAT IS DICTIONARY DATATYPE??
#ANS.) DICTIONARY IS A SET OF KEY-VALUE PAIRS DEFINED BY SQUARE BRACKETS i.e....[]
