# %%
#introduction to tuple datatype

# %%
tuple is an immutable datatype ---. WHICH CANNOT BE ALTERED ONCE ASSIGNED
tuple is assigned with ()

# %%
measurements=('hi','hello')

# %%
measurements[0]=('no')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-f906a1e30236> in <module>
# ----> 1 measurements[0]=('no')
#
# TypeError: 'tuple' object does not support item assignment

# %%
measurements=('no','hello')

# %%
print(measurements)
# Out:
# ('no', 'hello')
