# %%
#Implementation of loops in dictionary datatype

# %%
#REQ:students survey poll of their fav prog lang in a college.

# %%
favourite_languages={
    'sam':'python',
    'iswarya':'java',
    'shafi':'c',
    'pradeepa':'c++',
    'syed':'swift'
}

# %%
print(favourite_languages)
# Out:
# {'sam': 'python', 'iswarya': 'java', 'shafi': 'c', 'pradeepa': 'c++', 'syed': 'swift'}

# %%
type(favourite_languages)
# Out:
# dict

# %%
#REQ: to acess what isarya has selected

# %%
print(favourite_languages['iswarya'].title())
# Out:
# Java

# %%
#enhancing it

# %%
language=favourite_languages['iswarya'].title()

# %%
print(f" iswarya's fav language is {language}")
# Out:
#  iswarya's fav language is Java

# %%
user_0={'username':'codetraining01',
        'first':'code',
        'last':'training',
        'dob':'01-01-2019'
       }

# %%
print(user_0)
# Out:
# {'username': 'codetraining01', 'first': 'code', 'last': 'training', 'dob': '01-01-2019'}

# %%
#GENERAL SYNTAX OF A FOR LOOP:----->list and tuple

for tempvar in mainvar:
    print(tempvar)

# %%
#dict implimentation------>key,value


for temp1,temp2  in mainvar:
    print(temp1)
    print(temp2)

# %%
for key,value in user_0.items():
    print(key)
    print(value)
# Out:
# username
# codetraining01
# first
# code
# last
# training
# dob
# 01-01-2019

# %%
#enhancing the code

# %%
for k,v in user_0.items():
    print(f"\n key: {k}")
    print(f" value : {value}")
# Out:
#  key: username
#  value : 01-01-2019
#
#  key: first
#  value : 01-01-2019
#
#  key: last
#  value : 01-01-2019
#
#  key: dob
#  value : 01-01-2019

# %%
print(favourite_languages)
# Out:
# {'sam': 'python', 'iswarya': 'java', 'shafi': 'c', 'pradeepa': 'c++', 'syed': 'swift'}

# %%
for name,language in favourite_languages.items():
    print(f"{name.title()}'s favourite language is {language.title()}\n")
# Out:
# Sam's favourite language is Python
#
# Iswarya's favourite language is Java
#
# Shafi's favourite language is C
#
# Pradeepa's favourite language is C++
#
# Syed's favourite language is Swift

# %%
#LOOPING THROUGH ALL THE KEYS IN A DICT

# %%
for x in favourite_languages.keys():
    print(x)
# Out:
# sam
# iswarya
# shafi
# pradeepa
# syed

# %%
#LOOPING THROUGH ALL THE VALUES IN A DICT

# %%
for x in favourite_languages.values():
    print(x)
# Out:
# python
# java
# c
# c++
# swift
