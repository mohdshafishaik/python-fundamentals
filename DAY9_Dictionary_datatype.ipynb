# %%
#introduction to dictionary datatype:
#definition: a dictionary is a set of key-value pairs:
#defining dictionary:-------->{}
#classificatio : it is classified as mutable datatype------.WHICH CAN BE ALTERED

# %%
#a dict is used in all real world objects:

# %%
#REQ:creating a account in github,facebook,instagram......

# %%
account={'firstname':'suhail','lastname':'syed','gmailid':'suhailsyed0130@gmail.com','age':'17','password':'1234'}

# %%
type(account)
# Out:
# dict

# %%
print(account)
# Out:
# {'firstname': 'suhail', 'lastname': 'syed', 'gmailid': 'suhailsyed0130@gmail.com', 'age': '17', 'password': '1234'}

# %%
#REQ:i want access my gmailId

# %%
account['gmailid']
# Out:
# 'suhailsyed0130@gmail.com'

# %%
#REQ:i want to change my password

# %%
account['password']='7890'

# %%
print(account)
# Out:
# {'firstname': 'suhail', 'lastname': 'syed', 'gmailid': 'suhailsyed0130@gmail.com', 'age': '17', 'password': '7890'}

# %%
#REQ:adding relationship status

# %%
account['relation_status']='single'

# %%
print(account)
# Out:
# {'firstname': 'suhail', 'lastname': 'syed', 'gmailid': 'suhailsyed0130@gmail.com', 'age': '17', 'password': '7890', 'relation_status': 'single'}

# %%
#REQ:i want to delete my relationship_status

# %%
del account["relation_status"]

# %%
print(account)
# Out:
# {'gmailid': 'suhailsyed0130@gmail.com', 'age': '17', 'password': '7890', 'firstname': 'suhail', 'lastname': 'syed'}
